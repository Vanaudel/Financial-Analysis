# %% [markdown]
# ## IMPORT LIBRARIES AND SET SYSTEM OPTIONS

# %%
import pandas as pd

pd.set_option('display.max_columns', 1500)
pd.set_option('display.max_rows',1500)
pd.set_option('display.max_colwidth', None)

import pandas_profiling
from pandas_profiling import ProfileReport

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### MASTER DATA

# %%
master_data = pd.read_csv('C:\\Users\\vafolab\\Desktop\\Financial Analysis\\master_data.csv')
master_data.head()
# Out:
#    Unnamed: 0        Date       Open       High        Low      Close  \
# 0           0  2018-12-25  77.536101  78.291540  75.883584  75.940239
# 1           1  2018-12-26  76.667366  79.726882  75.619197  79.641891
# 2           2  2018-12-27  78.622045  80.671165  77.300030  80.605064
# 3           3  2018-12-28  80.727829  82.059289  79.726878  80.699501
# 4           4  2018-12-29  80.727829  82.059289  79.726878  80.699501
#
#       Volume  Dividends  Stock Splits ticker  Percent_Change_Open  \
# 0  1353300.0        0.0           0.0    ADI             0.000000
# 1  2519000.0        0.0           0.0    ADI            -0.011204
# 2  2070300.0        0.0           0.0    ADI             0.025496
# 3  2070700.0        0.0           0.0    ADI             0.026784
# 4  2070700.0        0.0           0.0    ADI             0.000000
#
#    Percent_Change_High  Percent_Change_Low  Percent_Change_Close  \
# 0             0.000000            0.000000              0.000000
# ...

# %% [markdown]
# ### META DATA

# %%
meta_data = pd.read_csv('C:\\Users\\vafolab\\Desktop\\Financial Analysis\\meta_data.csv')
meta_data = meta_data[['Category', 'Information', 'ticker']]
meta_data.columns
meta_data.head()
# Out:
# Index(['Category', 'Information', 'ticker'], dtype='object')
#               Category  \
# 0                  zip
# 1               sector
# 2    fullTimeEmployees
# 3  longBusinessSummary
# 4                 city
#
# ...

# %%
pwd
# Out:
# 'C:\\Users\\vafolab\\Desktop\\Financial Analysis'
